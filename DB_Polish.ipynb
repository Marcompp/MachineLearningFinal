# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
print("Hello World")
# Out:
# Hello World

# %%
df_yugi = pd.read_csv('dbs/yugi_comp.csv', index_col=0)
df_yugi.drop(['name'], inplace=True, axis=1)
df_yugi = df_yugi[df_yugi['text'].notna()]
df_yugi.head()
# Out:
#                       Name            Rarity  Price  isGood  \
# 0  XX-Saber Boggart Knight  Shatterfoil Rare   2.73    True
# 1            Gagaga Cowboy  Shatterfoil Rare   4.68    True
# 2        Forbidden Chalice  Shatterfoil Rare   2.09    True
# 3         Fairy Cheer Girl  Shatterfoil Rare   2.06    True
# 4          Exploder Dragon  Shatterfoil Rare   2.08    True
#
#                                                 text card_type  \
# 0  When this card is Normal Summoned: You can Spe...   monster
# 1  2 Level 4 monsters\r\n\r\nOnce per turn: You c...   monster
# 2  Target 1 face-up monster on the field; until t...     spell
# 3  2 Level 4 Fairy-Type monsters\r\n\r\nYou can d...   monster
# 4  If this card is destroyed by battle and sent t...   monster
#
#                      type family     atk     def  level    property
# 0  Beast-Warrior / Effect  earth  1900.0  1000.0    4.0         NaN
# 1  Warrior / Xyz / Effect  earth  1500.0  2400.0    4.0         NaN
# 2                     NaN    NaN     NaN     NaN    NaN  Quick-Play
# 3    Fairy / Xyz / Effect  light  1900.0  1500.0    4.0         NaN
# 4         Dragon / Effect  earth  1000.0     0.0    3.0         NaN

# %%
def getTribe(row):
    #if row["card_type"] == "monster":
    if type(row["type"]) is float or row["card_type"] == "skill":
        return math.nan
    return row["type"].split("/")[0].strip()
    #else:
    #    return math.nan

# %%
def getEffect(row):
    if row["card_type"] == "monster":
        typ =  row["type"].split("/")[-1].strip()
        if typ == "Effect":
            return typ
        else:
            return "Normal"
    else:
        return math.nan

# %%
extradeckmons = ['Xyz', 'Fusion', 'Synchro', 'Ritual', 'Toon', 'Link', 'Union', 'Gemini']
def getMonsType(row):
    if row["card_type"] == "monster":
        typ =  row["type"].split("/")
        if len(typ) >= 3 and typ[1].strip() in extradeckmons:
            return typ[1].strip()
    elif row["card_type"] == "skill":
        return math.nan
    else: 
        return row["type"]
    return math.nan

# %%
def getskills(row):
    if type(row["type"]) is float:
        return row["card_type"]
    typ =  row["type"].split("/")
    for ty in typ:
        if ty.strip().lower() == "skill":
            return "skill"  
    return row["card_type"]

# %%
def getDuelist(row):
    if (row["card_type"] != "skill") or (type(row["type"]) is float):
        return math.nan
    typ =  row["type"].split("/")
    return typ[0].strip()

# %%
def getProperty(row):
    if (row["card_type"] != "skill") or (type(row["type"]) is float) or len(row["type"].split("/")) > 3:
        return row["property"]
    typ =  row["type"].split("/")
    return typ[-1].strip()

# %%
df_yugi['card_type'] = df_yugi.apply(lambda row: getskills(row), axis=1)
df_yugi.head()
# Out:
#                       Name            Rarity  Price  isGood  \
# 0  XX-Saber Boggart Knight  Shatterfoil Rare   2.73    True
# 1            Gagaga Cowboy  Shatterfoil Rare   4.68    True
# 2        Forbidden Chalice  Shatterfoil Rare   2.09    True
# 3         Fairy Cheer Girl  Shatterfoil Rare   2.06    True
# 4          Exploder Dragon  Shatterfoil Rare   2.08    True
#
#                                                 text card_type  \
# 0  When this card is Normal Summoned: You can Spe...   monster
# 1  2 Level 4 monsters\r\n\r\nOnce per turn: You c...   monster
# 2  Target 1 face-up monster on the field; until t...     spell
# 3  2 Level 4 Fairy-Type monsters\r\n\r\nYou can d...   monster
# 4  If this card is destroyed by battle and sent t...   monster
#
#                      type family     atk     def  level    property
# 0  Beast-Warrior / Effect  earth  1900.0  1000.0    4.0         NaN
# 1  Warrior / Xyz / Effect  earth  1500.0  2400.0    4.0         NaN
# 2                     NaN    NaN     NaN     NaN    NaN  Quick-Play
# 3    Fairy / Xyz / Effect  light  1900.0  1500.0    4.0         NaN
# 4         Dragon / Effect  earth  1000.0     0.0    3.0         NaN

# %%
df_yugi['tribe'] = df_yugi.apply(lambda row: getTribe(row), axis=1)
df_yugi.head()
# Out:
#                       Name            Rarity  Price  isGood  \
# 0  XX-Saber Boggart Knight  Shatterfoil Rare   2.73    True
# 1            Gagaga Cowboy  Shatterfoil Rare   4.68    True
# 2        Forbidden Chalice  Shatterfoil Rare   2.09    True
# 3         Fairy Cheer Girl  Shatterfoil Rare   2.06    True
# 4          Exploder Dragon  Shatterfoil Rare   2.08    True
#
#                                                 text card_type  \
# 0  When this card is Normal Summoned: You can Spe...   monster
# 1  2 Level 4 monsters\r\n\r\nOnce per turn: You c...   monster
# 2  Target 1 face-up monster on the field; until t...     spell
# 3  2 Level 4 Fairy-Type monsters\r\n\r\nYou can d...   monster
# 4  If this card is destroyed by battle and sent t...   monster
#
#                      type family     atk     def  level    property  \
# 0  Beast-Warrior / Effect  earth  1900.0  1000.0    4.0         NaN
# 1  Warrior / Xyz / Effect  earth  1500.0  2400.0    4.0         NaN
# 2                     NaN    NaN     NaN     NaN    NaN  Quick-Play
# 3    Fairy / Xyz / Effect  light  1900.0  1500.0    4.0         NaN
# 4         Dragon / Effect  earth  1000.0     0.0    3.0         NaN
#
#            tribe
# 0  Beast-Warrior
# 1        Warrior
# 2            NaN
# 3          Fairy
# 4         Dragon

# %%
df_yugi['effect?'] = df_yugi.apply(lambda row: getEffect(row), axis=1)
df_yugi.head()
# Out:
#                       Name            Rarity  Price  isGood  \
# 0  XX-Saber Boggart Knight  Shatterfoil Rare   2.73    True
# 1            Gagaga Cowboy  Shatterfoil Rare   4.68    True
# 2        Forbidden Chalice  Shatterfoil Rare   2.09    True
# 3         Fairy Cheer Girl  Shatterfoil Rare   2.06    True
# 4          Exploder Dragon  Shatterfoil Rare   2.08    True
#
#                                                 text card_type  \
# 0  When this card is Normal Summoned: You can Spe...   monster
# 1  2 Level 4 monsters\r\n\r\nOnce per turn: You c...   monster
# 2  Target 1 face-up monster on the field; until t...     spell
# 3  2 Level 4 Fairy-Type monsters\r\n\r\nYou can d...   monster
# 4  If this card is destroyed by battle and sent t...   monster
#
#                      type family     atk     def  level    property  \
# 0  Beast-Warrior / Effect  earth  1900.0  1000.0    4.0         NaN
# 1  Warrior / Xyz / Effect  earth  1500.0  2400.0    4.0         NaN
# 2                     NaN    NaN     NaN     NaN    NaN  Quick-Play
# 3    Fairy / Xyz / Effect  light  1900.0  1500.0    4.0         NaN
# 4         Dragon / Effect  earth  1000.0     0.0    3.0         NaN
#
#            tribe effect?
# 0  Beast-Warrior  Effect
# 1        Warrior  Effect
# 2            NaN     NaN
# 3          Fairy  Effect
# 4         Dragon  Effect

# %%
df_yugi['Duelist'] = df_yugi.apply(lambda row: getDuelist(row), axis=1)
df_yugi.head()
# Out:
#                       Name            Rarity  Price  isGood  \
# 0  XX-Saber Boggart Knight  Shatterfoil Rare   2.73    True
# 1            Gagaga Cowboy  Shatterfoil Rare   4.68    True
# 2        Forbidden Chalice  Shatterfoil Rare   2.09    True
# 3         Fairy Cheer Girl  Shatterfoil Rare   2.06    True
# 4          Exploder Dragon  Shatterfoil Rare   2.08    True
#
#                                                 text card_type  \
# 0  When this card is Normal Summoned: You can Spe...   monster
# 1  2 Level 4 monsters\r\n\r\nOnce per turn: You c...   monster
# 2  Target 1 face-up monster on the field; until t...     spell
# 3  2 Level 4 Fairy-Type monsters\r\n\r\nYou can d...   monster
# 4  If this card is destroyed by battle and sent t...   monster
#
#                      type family     atk     def  level    property  \
# 0  Beast-Warrior / Effect  earth  1900.0  1000.0    4.0         NaN
# 1  Warrior / Xyz / Effect  earth  1500.0  2400.0    4.0         NaN
# 2                     NaN    NaN     NaN     NaN    NaN  Quick-Play
# 3    Fairy / Xyz / Effect  light  1900.0  1500.0    4.0         NaN
# 4         Dragon / Effect  earth  1000.0     0.0    3.0         NaN
#
#            tribe effect? Duelist
# 0  Beast-Warrior  Effect     NaN
# 1        Warrior  Effect     NaN
# 2            NaN     NaN     NaN
# 3          Fairy  Effect     NaN
# 4         Dragon  Effect     NaN

# %%
df_yugi['property'] = df_yugi.apply(lambda row: getProperty(row), axis=1)
df_yugi.head()
# Out:
#                       Name            Rarity  Price  isGood  \
# 0  XX-Saber Boggart Knight  Shatterfoil Rare   2.73    True
# 1            Gagaga Cowboy  Shatterfoil Rare   4.68    True
# 2        Forbidden Chalice  Shatterfoil Rare   2.09    True
# 3         Fairy Cheer Girl  Shatterfoil Rare   2.06    True
# 4          Exploder Dragon  Shatterfoil Rare   2.08    True
#
#                                                 text card_type  \
# 0  When this card is Normal Summoned: You can Spe...   monster
# 1  2 Level 4 monsters\r\n\r\nOnce per turn: You c...   monster
# 2  Target 1 face-up monster on the field; until t...     spell
# 3  2 Level 4 Fairy-Type monsters\r\n\r\nYou can d...   monster
# 4  If this card is destroyed by battle and sent t...   monster
#
#                      type family     atk     def  level    property  \
# 0  Beast-Warrior / Effect  earth  1900.0  1000.0    4.0         NaN
# 1  Warrior / Xyz / Effect  earth  1500.0  2400.0    4.0         NaN
# 2                     NaN    NaN     NaN     NaN    NaN  Quick-Play
# 3    Fairy / Xyz / Effect  light  1900.0  1500.0    4.0         NaN
# 4         Dragon / Effect  earth  1000.0     0.0    3.0         NaN
#
#            tribe effect? Duelist
# 0  Beast-Warrior  Effect     NaN
# 1        Warrior  Effect     NaN
# 2            NaN     NaN     NaN
# 3          Fairy  Effect     NaN
# 4         Dragon  Effect     NaN

# %%
df_yugi[df_yugi['card_type'] == "skill"]
# Out:
#                                    Name      Rarity  Price  isGood  \
# 108              Nightmare Sonic Blast!      Common   3.73    True
# 114                       Fusion Party!      Common   3.82    True
# 115                     Ritual Ceremony      Common   4.47    True
# 119                 Twisted Personality      Common   2.69    True
# 125                      Inner Conflict      Common   2.04    True
# ...                                 ...         ...    ...     ...
# 11393  Heavy Metal Raiders (Skill Card)  Ultra Rare   4.30   False
# 11494               Tomb of the Pharaoh  Ultra Rare   2.96   False
# 11501  Call of the Haunted (Skill Card)  Ultra Rare   3.84   False
# 11524                   Viral Infection  Ultra Rare   3.12   False
# 11525    The World's Greatest Fisherman  Ultra Rare   1.81   False
#
#                                                     text card_type  \
# 108    Activate this Skill while the only monster you...     skill
# 114    Once per Duel, during your Main Phase, you can...     skill
# 115    Once per Duel, during your Main Phase, you can...     skill
# 119    Each time you lose LP, place 1 counter on this...     skill
# 125    Once per Duel, during your Main Phase, you can...     skill
# ...                                                  ...       ...
# 11393  The first time each DARK Machine monster you c...     skill
# 11494  This card's name is always treated as "Necrova...     skill
# 11501  Activate this card by targeting 1 monster in y...     skill
# 11524  Once per turn, discard any number of cards and...     skill
# 11525  Once per turn, you can pay 500 LP and discard ...     skill
#
#                                  type family  atk  def  level  \
# 108                       Rex / Skill    NaN  0.0  0.0    0.0
# 114                 Christine / Skill    NaN  0.0  0.0    0.0
# 115                      Emma / Skill    NaN  0.0  0.0    0.0
# 119                Yami Marik / Skill    NaN  0.0  0.0    0.0
# 125               Yami Bakura / Skill    NaN  0.0  0.0    0.0
# ...                               ...    ...  ...  ...    ...
# 11393     Keith / Skill / Field Spell    NaN  0.0  0.0    0.0
# 11494    Ishizu / Skill / Field Spell    NaN  0.0  0.0    0.0
# 11501  Bonz / Skill / Continuous Trap    NaN  0.0  0.0    0.0
# 11524                   Kaiba / Skill    NaN  0.0  0.0    0.0
# 11525                    Mako / Skill    NaN  0.0  0.0    0.0
#
#               property tribe effect?      Duelist
# 108              Skill   NaN     NaN          Rex
# 114              Skill   NaN     NaN    Christine
# 115              Skill   NaN     NaN         Emma
# 119              Skill   NaN     NaN   Yami Marik
# 125              Skill   NaN     NaN  Yami Bakura
# ...                ...   ...     ...          ...
# 11393      Field Spell   NaN     NaN        Keith
# 11494      Field Spell   NaN     NaN       Ishizu
# 11501  Continuous Trap   NaN     NaN         Bonz
# 11524            Skill   NaN     NaN        Kaiba
# 11525            Skill   NaN     NaN         Mako
#
# [102 rows x 15 columns]

# %%
df_yugi['monsType'] = df_yugi.apply(lambda row: getMonsType(row), axis=1)
df_yugi.head()
# Out:
#                       Name            Rarity  Price  isGood  \
# 0  XX-Saber Boggart Knight  Shatterfoil Rare   2.73    True
# 1            Gagaga Cowboy  Shatterfoil Rare   4.68    True
# 2        Forbidden Chalice  Shatterfoil Rare   2.09    True
# 3         Fairy Cheer Girl  Shatterfoil Rare   2.06    True
# 4          Exploder Dragon  Shatterfoil Rare   2.08    True
#
#                                                 text card_type  \
# 0  When this card is Normal Summoned: You can Spe...   monster
# 1  2 Level 4 monsters\r\n\r\nOnce per turn: You c...   monster
# 2  Target 1 face-up monster on the field; until t...     spell
# 3  2 Level 4 Fairy-Type monsters\r\n\r\nYou can d...   monster
# 4  If this card is destroyed by battle and sent t...   monster
#
#                      type family     atk     def  level    property  \
# 0  Beast-Warrior / Effect  earth  1900.0  1000.0    4.0         NaN
# 1  Warrior / Xyz / Effect  earth  1500.0  2400.0    4.0         NaN
# 2                     NaN    NaN     NaN     NaN    NaN  Quick-Play
# 3    Fairy / Xyz / Effect  light  1900.0  1500.0    4.0         NaN
# 4         Dragon / Effect  earth  1000.0     0.0    3.0         NaN
#
#            tribe effect? Duelist monsType
# 0  Beast-Warrior  Effect     NaN      NaN
# 1        Warrior  Effect     NaN      Xyz
# 2            NaN     NaN     NaN      NaN
# 3          Fairy  Effect     NaN      Xyz
# 4         Dragon  Effect     NaN      NaN

# %%
df_yugi.shape
# Out:
# (11574, 16)

# %%
extradeckmons = set(df_yugi["monsType"].unique())
extradeckmons.remove(math.nan)
extradeckmons
# Out:
# {'Fusion', 'Gemini', 'Link', 'Ritual', 'Synchro', 'Toon', 'Union', 'Xyz'}

# %%
# extradeckmons = ['Xyz', 'Fusion', 'Synchro', 'Ritual', 'Toon', 'Link', 'Union', 'Gemini', 'Skill']

othertype  = ['Spirit','Flip']

def getMonsType2(row):
    monst = ""
    if type(row["type"]) is float:
        return math.nan
    #print(row["type"])
    for word in row["type"].split("/"):
            if word.strip() in othertype:
                monst += word.strip() 
    if monst == "":
        return math.nan
    else:
        return monst

# %%
def getMonsType3(row):
    if row["card_type"] == "monster":
        typ =  row["type"].split("/")
        for ty in typ:
            typp = ty.strip()
            if typp == "Tuner":
                return "Tuner"
        
    return math.nan

# %%
def getMonsType4(row):
    if row["card_type"] == "monster":
        typ =  row["type"].split("/")
        for ty in typ:
            typp = ty.strip()
            if typp == "Pendulum":
                return "Pendulum"
        
    return math.nan

# %%
df_yugi['monsType2'] = df_yugi.apply(lambda row: getMonsType2(row), axis=1)
df_yugi['Tuner?'] = df_yugi.apply(lambda row: getMonsType3(row), axis=1)
df_yugi['Pendulum?'] = df_yugi.apply(lambda row: getMonsType4(row), axis=1)
df_yugi.head()
# Out:
#                       Name            Rarity  Price  isGood  \
# 0  XX-Saber Boggart Knight  Shatterfoil Rare   2.73    True
# 1            Gagaga Cowboy  Shatterfoil Rare   4.68    True
# 2        Forbidden Chalice  Shatterfoil Rare   2.09    True
# 3         Fairy Cheer Girl  Shatterfoil Rare   2.06    True
# 4          Exploder Dragon  Shatterfoil Rare   2.08    True
#
#                                                 text card_type  \
# 0  When this card is Normal Summoned: You can Spe...   monster
# 1  2 Level 4 monsters\r\n\r\nOnce per turn: You c...   monster
# 2  Target 1 face-up monster on the field; until t...     spell
# 3  2 Level 4 Fairy-Type monsters\r\n\r\nYou can d...   monster
# 4  If this card is destroyed by battle and sent t...   monster
#
#                      type family     atk     def  level    property  \
# 0  Beast-Warrior / Effect  earth  1900.0  1000.0    4.0         NaN
# 1  Warrior / Xyz / Effect  earth  1500.0  2400.0    4.0         NaN
# 2                     NaN    NaN     NaN     NaN    NaN  Quick-Play
# 3    Fairy / Xyz / Effect  light  1900.0  1500.0    4.0         NaN
# 4         Dragon / Effect  earth  1000.0     0.0    3.0         NaN
#
#            tribe effect? Duelist monsType monsType2 Tuner? Pendulum?
# 0  Beast-Warrior  Effect     NaN      NaN       NaN    NaN       NaN
# 1        Warrior  Effect     NaN      Xyz       NaN    NaN       NaN
# 2            NaN     NaN     NaN      NaN       NaN    NaN       NaN
# 3          Fairy  Effect     NaN      Xyz       NaN    NaN       NaN
# 4         Dragon  Effect     NaN      NaN       NaN    NaN       NaN

# %%
print(df_yugi["monsType"].unique())
print(df_yugi["monsType2"].unique())
print(df_yugi["Tuner?"].unique())
print(df_yugi["Pendulum?"].unique())
# Out:
# [nan 'Xyz' 'Fusion' 'Synchro' 'Ritual' 'Toon' 'Link' 'Union' 'Gemini']
# [nan 'Flip' 'Spirit']
# [nan 'Tuner']
# [nan 'Pendulum']

# %%
df_yugi["monsType"].unique()
# Out:
# array([nan, 'Xyz', 'Fusion', 'Synchro', 'Ritual', 'Toon', 'Link', 'Union',
#        'Gemini'], dtype=object)

# %%
print(df_yugi["tribe"].unique())
# Out:
# ['Beast-Warrior' 'Warrior' nan 'Fairy' 'Dragon' 'Aqua' 'Zombie' 'Rock'
#  'Beast' 'Insect' 'Sea Serpent' 'Fiend' 'Reptile' 'Plant' 'Thunder'
#  'Spellcaster' 'Machine' 'Winged Beast' 'Divine-Beast' 'Dinosaur' 'Pyro'
#  'Fish' 'Normal' 'Psychic' 'Cyberse' 'Wyrm' 'Token']

# %%
df_yugi[df_yugi["tribe"] == "Keith"]
# Out:
# Empty DataFrame
# Columns: [Name, Rarity, Price, isGood, text, card_type, type, family, atk, def, level, property, tribe, effect?, Duelist, monsType, monsType2, Tuner?, Pendulum?]
# Index: []

# %%
df_yugi.reset_index(drop=True, inplace=True)

# %%
df_yugi
# Out:
#                                 Name            Rarity  Price  isGood  \
# 0            XX-Saber Boggart Knight  Shatterfoil Rare   2.73    True
# 1                      Gagaga Cowboy  Shatterfoil Rare   4.68    True
# 2                  Forbidden Chalice  Shatterfoil Rare   2.09    True
# 3                   Fairy Cheer Girl  Shatterfoil Rare   2.06    True
# 4                    Exploder Dragon  Shatterfoil Rare   2.08    True
# ...                              ...               ...    ...     ...
# 11569        Herald of Mirage Lights        Ultra Rare   1.55   False
# 11570   Graveyard of Wandering Souls        Ultra Rare   1.39   False
# 11571  Lib the World Key Blademaster        Ultra Rare   3.47   False
# 11572                   Kingyo Sukui        Ultra Rare   1.22   False
# 11573               Skydive Scorcher        Ultra Rare   1.58   False
#
#                                                     text card_type  \
# 0      When this card is Normal Summoned: You can Spe...   monster
# 1      2 Level 4 monsters\r\n\r\nOnce per turn: You c...   monster
# 2      Target 1 face-up monster on the field; until t...     spell
# 3      2 Level 4 Fairy-Type monsters\r\n\r\nYou can d...   monster
# 4      If this card is destroyed by battle and sent t...   monster
# ...                                                  ...       ...
# 11569  2 monsters with the same Type and Attribute, e...   monster
# 11570  If this card is already face-up on the field:\...      trap
# 11571  2 monsters\r\n\r\nCan only be Link Summoned wh...   monster
# 11572  You can target 1 monster in your opponent's GY...      trap
# 11573  Target 1 "Elemental HERO" Fusion Monster you c...     spell
#
#                           type family     atk     def  level    property  \
# 0       Beast-Warrior / Effect  earth  1900.0  1000.0    4.0         NaN
# 1       Warrior / Xyz / Effect  earth  1500.0  2400.0    4.0         NaN
# 2                          NaN    NaN     NaN     NaN    NaN  Quick-Play
# 3         Fairy / Xyz / Effect  light  1900.0  1500.0    4.0         NaN
# 4              Dragon / Effect  earth  1000.0     0.0    3.0         NaN
# ...                        ...    ...     ...     ...    ...         ...
# 11569    Fairy / Link / Effect  light   600.0     0.0    0.0         NaN
# 11570                      NaN    NaN     NaN     NaN    NaN  Continuous
# 11571  Cyberse / Link / Effect  light  2000.0     0.0    0.0         NaN
# 11572                      NaN    NaN     NaN     NaN    NaN  Continuous
# 11573                      NaN    NaN     NaN     NaN    NaN      Normal
#
#                tribe effect? Duelist monsType monsType2 Tuner? Pendulum?
# 0      Beast-Warrior  Effect     NaN      NaN       NaN    NaN       NaN
# 1            Warrior  Effect     NaN      Xyz       NaN    NaN       NaN
# 2                NaN     NaN     NaN      NaN       NaN    NaN       NaN
# 3              Fairy  Effect     NaN      Xyz       NaN    NaN       NaN
# 4             Dragon  Effect     NaN      NaN       NaN    NaN       NaN
# ...              ...     ...     ...      ...       ...    ...       ...
# 11569          Fairy  Effect     NaN     Link       NaN    NaN       NaN
# 11570            NaN     NaN     NaN      NaN       NaN    NaN       NaN
# 11571        Cyberse  Effect     NaN     Link       NaN    NaN       NaN
# 11572            NaN     NaN     NaN      NaN       NaN    NaN       NaN
# 11573            NaN     NaN     NaN      NaN       NaN    NaN       NaN
#
# [11574 rows x 19 columns]

# %%
df_yugi.drop(columns=['type', 'isGood'], inplace=True)

mapper_dict = { 
                'text': 'Description', 
                'card_type': 'CardType',
                'family': 'Attribute',
                'atk': 'ATK',
                'def': 'DEF', 
                'level': 'LVL', 
                'property': 'Property', 
                'tribe': 'MonsterType',
                'effect?': 'isEffect',
                'monsType': 'Ability1',
                'monsType2': 'Ability2',
                'Tuner?': 'isTuner',
                'Pendulum?': 'isPendulum'
              }

df_yugi.rename(mapper=mapper_dict, axis=1, inplace=True)
df_yugi.to_csv("dbs/yugi_db_polished.csv")
